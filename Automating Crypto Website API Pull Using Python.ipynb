# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'a2bc73c5-e9a0-4569-8e0f-8bb48115bbee',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# C:\Users\MANUEL-PC\AppData\Local\Temp\ipykernel_8912\2161189289.py:3: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10196
# 1   1027     Ethereum    ETH      ethereum              6800
# 2    825       Tether   USDT        tether             52281
# 3   1839          BNB    BNB           bnb              1302
# 4   3408     USD Coin   USDC      usd-coin             12084
# 5     52          XRP    XRP           xrp               939
# 6   2010      Cardano    ADA       cardano               773
# 7     74     Dogecoin   DOGE      dogecoin               698
# 8   3890      Polygon  MATIC       polygon               677
# 9   5426       Solana    SOL        solana               458
# 10  6636     Polkadot    DOT  polkadot-new               499
# 11     2     Litecoin    LTC      litecoin               909
# 12  4687  Binance USD   BUSD   binance-usd              6673
# 13  1958         TRON    TRX          tron               754
# 14  5994    Shiba Inu   SHIB     shiba-inu               508
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2020-08-19T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2019-09-20T00:00:00.000Z
# 13  2017-09-13T00:00:00.000Z
# 14  2020-08-01T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 10  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 13                  [media, payments, tron-ecosystem]           NaN
# 14      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.935898e+07  1.935898e+07            False       NaN         1
# 1         1.203984e+08  1.203984e+08            False       NaN         2
# 2         8.161554e+10  8.509064e+10            False       NaN         3
# 3         1.558630e+08  1.558630e+08            False       NaN         4
# 4         3.050266e+10  3.050266e+10            False       NaN         5
# 5         5.175081e+10  9.998900e+10            False       NaN         6
# 6         3.480523e+10  3.572784e+10            False       NaN         7
# 7         1.391334e+11  1.391334e+11            False       NaN         8
# 8         9.249469e+09  1.000000e+10            False       NaN         9
# 9         3.930288e+08  5.393127e+08            False       NaN        10
# 10        1.178450e+09  1.307929e+09            False       NaN        11
# 11        7.280788e+07  8.400000e+07            False       NaN        12
# 12        6.197080e+09  6.197080e+09            False       NaN        13
# 13        9.064267e+10  9.064271e+10            False       NaN        14
# 14        5.895447e+14  5.896048e+14            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                      7.165966e+10              4.821076e+09      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-04-29T05:28:00.000Z     29414.631901          1.634357e+10
# 1   2023-04-29T05:28:00.000Z      1903.121874          7.012123e+09
# 2   2023-04-29T05:28:00.000Z         1.000752          2.588865e+10
# 3   2023-04-29T05:28:00.000Z       323.930598          1.007956e+09
# 4   2023-04-29T05:28:00.000Z         0.999893          3.904898e+09
# 5   2023-04-29T05:28:00.000Z         0.480349          1.060639e+09
# 6   2023-04-29T05:28:00.000Z         0.405458          2.203225e+08
# 7   2023-04-29T05:28:00.000Z         0.081163          2.658148e+08
# 8   2023-04-29T05:28:00.000Z         1.006286          3.810901e+08
# 9   2023-04-29T05:28:00.000Z        23.336299          5.058435e+08
# 10  2023-04-29T05:28:00.000Z         5.996320          1.428388e+08
# 11  2023-04-29T05:28:00.000Z        90.016399          4.235081e+08
# 12  2023-04-29T05:28:00.000Z         1.000343          2.573919e+09
# 13  2023-04-29T05:28:00.000Z         0.067277          1.603582e+08
# 14  2023-04-29T05:28:00.000Z         0.000010          8.421819e+07
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -31.1177                    -0.052180
# 1                      -31.6678                    -0.035849
# 2                      -17.2877                    -0.002009
# 3                       34.5476                    -0.238463
# 4                      -15.9693                    -0.007289
# 5                        0.6899                    -0.366867
# 6                      -36.8186                    -0.123269
# 7                      -25.1492                     0.101888
# 8                      -20.1247                    -0.229792
# 9                       20.2131                    -0.262511
# 10                     -11.5136                    -0.112098
# 11                     -12.2776                    -0.064395
# 12                     -17.9247                    -0.013336
# 13                      -9.7263                     0.174421
# 14                     -18.7758                    -0.127853
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.314299                     7.579454
# 1                      -0.589629                     2.277730
# 2                       0.042185                     0.057396
# 3                      -1.009515                     0.115988
# 4                      -0.011831                    -0.029895
# 5                       0.015497                     6.325890
# 6                      -1.115441                     4.957654
# 7                       1.016271                     2.643439
# 8                      -0.472000                    -1.462181
# 9                       4.255549                     9.109070
# 10                      0.716291                     1.730699
# 11                      0.357048                     5.066346
# 12                      0.030400                     0.023728
# 13                      1.793659                     3.310330
# 14                      0.400478                     0.097748
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       3.204660                     25.495953
# 1                       6.222993                     16.848667
# 2                       0.073407                      0.062084
# 3                       3.537958                      6.541550
# 4                       0.001316                     -0.012016
# 5                      -9.307594                     27.398044
# 6                       7.745346                     10.991559
# 7                       8.018633                     -1.541093
# 8                      -9.880125                    -18.067989
# 9                      10.508765                      4.029216
# 10                     -3.084612                     -8.606422
# 11                     -0.140780                     -4.280015
# 12                      0.051393                      0.013950
# 13                      4.370346                     -3.438792
# 14                     -2.945048                    -17.433382
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      26.740200          5.694371e+11
# 1                      19.267910          2.291328e+11
# 2                       0.047435          8.167695e+10
# 3                       5.159559          5.048880e+10
# 4                      -0.024112          3.049940e+10
# 5                      17.035242          2.485843e+10
# 6                       4.877856          1.411206e+10
# 7                      -8.401149          1.129243e+10
# 8                     -12.284679          9.307607e+09
# 9                      -3.075930          9.171838e+09
# 10                     -7.755996          7.066365e+09
# 11                     -5.249692          6.553903e+09
# 12                      0.028297          6.199208e+09
# 13                      6.380986          6.098204e+09
# 14                    -13.538801          6.089965e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          47.0881                        6.177073e+11
# 1                          18.9462                        2.291328e+11
# 2                           6.7538                        8.515466e+10
# 3                           4.1748                        5.048880e+10
# 4                           2.5224                        3.049940e+10
# 5                           2.0556                        4.803486e+10
# 6                           1.1671                        1.824562e+10
# 7                           0.9338                        1.129243e+10
# 8                           0.7696                        1.006286e+10
# 9                           0.7584                        1.258556e+10
# 10                          0.5843                        7.842761e+09
# 11                          0.5420                        7.561377e+09
# 12                          0.5126                        6.199208e+09
# 13                          0.5043                        6.098206e+09
# 14                          0.5036                        6.090586e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 1           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 2           None  2023-04-29T05:28:00.000Z       1027.0      Ethereum
# 3           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 4           None  2023-04-29T05:28:00.000Z       1027.0      Ethereum
# 5           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 6           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 7           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 8           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 9           None  2023-04-29T05:28:00.000Z          NaN           NaN
# 10          None  2023-04-29T05:28:00.000Z          NaN           NaN
# 11          None  2023-04-29T05:28:00.000Z          NaN           NaN
# 12          None  2023-04-29T05:28:00.000Z       1839.0           BNB
# 13          None  2023-04-29T05:28:00.000Z          NaN           NaN
# 14          None  2023-04-29T05:28:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             BNB           bnb                                    BUSD-BD1
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                     timestamp
# 0  2023-04-29 05:48:17.304445
# 1  2023-04-29 05:48:17.304445
# 2  2023-04-29 05:48:17.304445
# 3  2023-04-29 05:48:17.304445
# 4  2023-04-29 05:48:17.304445
# 5  2023-04-29 05:48:17.304445
# 6  2023-04-29 05:48:17.304445
# 7  2023-04-29 05:48:17.304445
# 8  2023-04-29 05:48:17.304445
# 9  2023-04-29 05:48:17.304445
# 10 2023-04-29 05:48:17.304445
# 11 2023-04-29 05:48:17.304445
# 12 2023-04-29 05:48:17.304445
# 13 2023-04-29 05:48:17.304445
# 14 2023-04-29 05:48:17.304445

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
     'X-CMC_PRO_API_KEY': 'a2bc73c5-e9a0-4569-8e0f-8bb48115bbee',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data
    
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('Api Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3 from time import sleep
#       5 for i in range(333):
# ----> 6     api_runner()
#       7     print('API Runner completed')
#       8     sleep(60) #sleep for 1 minute
#
# Cell In[5], line 30, in api_runner()
#      23       print(e)
#      25 #NOTE:
#      26 # I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
#      27 # Into the Anaconda Prompt to change this to allow to pull data
#      28
#      29     # Use this if you just want to keep it in a dataframe
# ---> 30     df2 = pd.json_normalize(data['data'])
#      31     df2['Timestamp'] = pd.to_datetime('now')
#      32     df = df.append(df2)
#
# NameError: name 'pd' is not defined

# %%
df72 = pd.read_csv(r'C:\Users\manuelpc\OneDrive\Documents\Python Scripts\API.csv')
df72

# %%
df

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3

# %%
df4 = df3.stack()
df4

# %%
type(df4)

# %%
df5 = df4.to_frame(name='values')
df5

# %%
df5.count()

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.set_index(index)
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
